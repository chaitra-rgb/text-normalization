# %%
pip install emoji
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import emoji

# %%
s = 'hellllooooo😊'
emoji.replace_emoji(s,'')
# Out:
# 'hellllooooo'

# %%
s = 'hiiiiiiiiiii(❁´◡`❁)'
emoji.replace_emoji(s,'')
# Out:
# 'hiiiiiiiiiii(❁´◡`❁)'

# %%
# sentiment analysis
s = 'hellllooooo😊'
emoji.demojize(s)
# Out:
# 'hellllooooo:smiling_face_with_smiling_eyes:'

# %%
s = 'hellllooooo😊🤷‍♀️🤦‍♀️'
emoji.demojize(s)
# Out:
# 'hellllooooo:smiling_face_with_smiling_eyes::woman_shrugging::woman_facepalming:'

# %%
s1 = 'i    am   good'
s1.split()
" ".join(s1.split())
# Out:
# 'i am good'

# %%
with open('data.txt','r') as file:
    data = file.read()
    words = data.split()
    data = " ".join(data.split())
print(data)
# Out:
# python is a high level , @@object oriented and &&programming language.
