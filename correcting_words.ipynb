# %%
pip install textblob
# Out:
# ...
#   Using cached textblob-0.20.0-py3-none-any.whl.metadata (4.0 kB)
# ...
# Using cached textblob-0.20.0-py3-none-any.whl (624 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob

# %%
text = 'corrcting the wods for txt normaliation'
text1 = 'the rouger is not woking'

corrected_words = TextBlob(text).correct()
print(type(corrected_words),corrected_words)
# Out:
# <class 'textblob.blob.TextBlob'> correcting the words for txt normaliation
